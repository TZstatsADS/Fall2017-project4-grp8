# %%
import numpy as np
import pandas as pd

# %%
movie_train = pd.read_csv("../data/eachmovie_sample/data_train.csv")
movie_test = pd.read_csv("../data/eachmovie_sample/data_test.csv")
web_train = pd.read_csv("../data/MS_sample/data_train.csv")
web_test = pd.read_csv("../data/MS_sample/data_test.csv")

# %%
web_train.shape, web_test.shape, movie_train.shape, movie_test.shape
# Out:
# ((38026, 4), (2718, 4), (809526, 4), (199876, 4))

# %%
'1' in web_train
# Out:
# False

# %%
web_train
# Out:
#        Unnamed: 0 V1     V2     V3
# 0               1  C  10010  10010
# 1               2  V   1010      1
# 2               3  V   1000      1
# 3               4  V   1011      1
# 4               5  V   1012      1
# 5               6  V   1013      1
# 6               7  V   1014      1
# 7               8  C  10019  10019
# 8               9  V   1017      1
# 9              10  V   1004      1
# 10             11  V   1018      1
# 11             12  V   1029      1
# 12             13  V   1008      1
# 13             14  V   1030      1
# 14             15  V   1031      1
# 15             16  V   1032      1
# 16             17  V   1003      1
# 17             18  V   1033      1
# 18             19  V   1002      1
# 19             20  C  10021  10021
# 20             21  V   1017      1
# 21             22  V   1004      1
# 22             23  V   1018      1
# 23             24  V   1035      1
# 24             25  V   1036      1
# 25             26  V   1008      1
# 26             27  V   1037      1
# 27             28  V   1009      1
# 28             29  V   1038      1
# 29             30  V   1026      1
# ...           ... ..    ...    ...
# 37996       37997  V   1024      1
# 37997       37998  V   1008      1
# 37998       37999  V   1027      1
# 37999       38000  V   1038      1
# 38000       38001  V   1009      1
# 38001       38002  V   1026      1
# 38002       38003  V   1041      1
# 38003       38004  C  42698  42698
# 38004       38005  V   1010      1
# 38005       38006  V   1005      1
# 38006       38007  V   1040      1
# 38007       38008  V   1003      1
# 38008       38009  V   1013      1
# 38009       38010  V   1001      1
# 38010       38011  V   1014      1
# 38011       38012  V   1004      1
# 38012       38013  C  42707  42707
# 38013       38014  V   1008      1
# 38014       38015  V   1030      1
# 38015       38016  V   1009      1
# 38016       38017  V   1058      1
# 38017       38018  V   1004      1
# 38018       38019  V   1018      1
# 38019       38020  C  42708  42708
# 38020       38021  V   1008      1
# 38021       38022  V   1027      1
# 38022       38023  V   1123      1
# 38023       38024  V   1038      1
# 38024       38025  V   1026      1
# 38025       38026  V   1041      1
#
# [38026 rows x 4 columns]
