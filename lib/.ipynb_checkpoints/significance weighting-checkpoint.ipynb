# %% [markdown]
# ## AUTHOR: Sijian Xuan
# ### make the adjacent list into the wei(not in matrix yet)

# %%
import csv
import pandas as pd

# %%
data = '../data/web.train2.0.csv'
data1 = '../data/movie.train2.0.csv'

# %%
webtrain = pd.read_csv(data, header= 0)
movietrain = pd.read_csv(data1, header = 0)

# %%
m = webtrain.shape[0]
a = []
print(m)
# Out:
# 4151

# %%
movietrain_numpyarray = pd.DataFrame.as_matrix(movietrain)

# %%
m1 = movietrain.shape[0]
a1 = []

# %%
for x in range(m1):
    for y in range(m1):
        a1.append(sum(movietrain_numpyarray[x,] == movietrain_numpyarray[y,]))
    print(x)

# %%
a1
# Out:
# [373, 12, 27, 12, 106, 13, 27, 13, 220]

# %%
movietrain
# Out:
#        User  Score.1  Score.2  Score.17  Score.18  Score.25  Score.31  \
# 0         1      4.0      4.0       5.0       2.0       5.0       2.0
# 1        23      5.0      NaN       1.0       NaN       5.0       NaN
# 2        27      6.0      5.0       6.0       2.0       5.0       NaN
# 3        71      NaN      5.0       4.0       NaN       4.0       NaN
# 4       119      5.0      NaN       NaN       5.0       NaN       5.0
# 5       160      NaN      NaN       5.0       NaN       NaN       3.0
# 6       162      NaN      NaN       5.0       NaN       6.0       1.0
# 7       245      NaN      NaN       NaN       5.0       4.0       NaN
# 8       251      6.0      NaN       5.0       NaN       5.0       NaN
# 9       254      6.0      4.0       NaN       NaN       6.0       1.0
# 10      286      NaN      NaN       NaN       NaN       NaN       NaN
# 11      305      6.0      4.0       NaN       NaN       3.0       4.0
# 12      332      4.0      NaN       6.0       NaN       4.0       NaN
# 13      390      4.0      1.0       NaN       NaN       NaN       NaN
# 14      489      1.0      4.0       NaN       NaN       NaN       NaN
# 15      502      5.0      NaN       NaN       5.0       NaN       NaN
# 16      546      NaN      4.0       NaN       NaN       NaN       NaN
# 17      599      5.0      1.0       6.0       1.0       3.0       NaN
# 18      622      5.0      NaN       NaN       NaN       5.0       NaN
# 19      661      6.0      2.0       1.0       5.0       NaN       1.0
# 20      686      4.0      4.0       5.0       NaN       NaN       NaN
# 21      749      NaN      6.0       4.0       NaN       NaN       NaN
# 22      775      NaN      4.0       NaN       NaN       5.0       NaN
# 23      791      NaN      6.0       NaN       NaN       1.0       5.0
# 24      833      6.0      NaN       6.0       NaN       NaN       NaN
# 25      854      NaN      NaN       6.0       NaN       1.0       NaN
# 26      875      6.0      NaN       5.0       2.0       5.0       NaN
# 27      979      5.0      3.0       NaN       NaN       NaN       5.0
# 28     1037      NaN      5.0       NaN       NaN       NaN       NaN
# 29     1069      6.0      NaN       NaN       NaN       NaN       NaN
# ...     ...      ...      ...       ...       ...       ...       ...
# 5025  74083      5.0      NaN       6.0       NaN       NaN       NaN
# 5026  74094      6.0      4.0       NaN       NaN       NaN       NaN
# 5027  74103      NaN      4.0       NaN       NaN       NaN       NaN
# 5028  74109      6.0      NaN       NaN       NaN       6.0       NaN
# 5029  74127      6.0      4.0       NaN       4.0       6.0       NaN
# 5030  74138      4.0      4.0       5.0       NaN       NaN       NaN
# 5031  74161      6.0      NaN       NaN       NaN       NaN       NaN
# 5032  74181      NaN      NaN       NaN       NaN       NaN       NaN
# 5033  74184      NaN      NaN       NaN       NaN       NaN       5.0
# 5034  74186      4.0      NaN       NaN       NaN       1.0       NaN
# 5035  74189      NaN      5.0       NaN       NaN       NaN       6.0
# 5036  74190      6.0      2.0       NaN       NaN       6.0       NaN
# 5037  74203      NaN      NaN       NaN       NaN       NaN       NaN
# 5038  74230      6.0      NaN       NaN       NaN       6.0       NaN
# 5039  74250      6.0      NaN       NaN       NaN       NaN       NaN
# 5040  74270      3.0      NaN       NaN       NaN       NaN       NaN
# 5041  74302      NaN      1.0       NaN       1.0       5.0       NaN
# 5042  74306      4.0      NaN       NaN       NaN       4.0       NaN
# 5043  74324      NaN      NaN       NaN       NaN       5.0       NaN
# 5044  74328      1.0      NaN       NaN       NaN       5.0       NaN
# 5045  74338      5.0      NaN       NaN       NaN       NaN       NaN
# 5046  74352      6.0      NaN       NaN       NaN       6.0       NaN
# 5047  74353      4.0      NaN       NaN       NaN       NaN       NaN
# 5048  74364      NaN      NaN       NaN       NaN       3.0       NaN
# 5049  74397      NaN      3.0       6.0       NaN       NaN       NaN
# 5050  74404      5.0      NaN       NaN       NaN       NaN       2.0
# 5051  74406      6.0      NaN       NaN       NaN       NaN       NaN
# 5052  74409      4.0      2.0       NaN       NaN       4.0       NaN
# 5053  74413      6.0      NaN       6.0       NaN       6.0       NaN
# 5054  74418      1.0      NaN       NaN       NaN       6.0       NaN
#
#       Score.32  Score.34  Score.36     ...      Score.1578  Score.1622  \
# 0          4.0       5.0       3.0     ...             NaN         NaN
# 1          5.0       5.0       6.0     ...             NaN         NaN
# 2          5.0       5.0       6.0     ...             NaN         NaN
# 3          NaN       2.0       NaN     ...             NaN         NaN
# 4          6.0       5.0       6.0     ...             NaN         NaN
# 5          5.0       6.0       6.0     ...             NaN         NaN
# 6          5.0       5.0       6.0     ...             NaN         NaN
# 7          6.0       5.0       4.0     ...             NaN         NaN
# 8          5.0       NaN       5.0     ...             NaN         NaN
# 9          5.0       NaN       5.0     ...             NaN         NaN
# 10         6.0       5.0       5.0     ...             NaN         NaN
# 11         NaN       4.0       4.0     ...             NaN         NaN
# 12         4.0       5.0       NaN     ...             NaN         NaN
# 13         NaN       NaN       NaN     ...             NaN         NaN
# 14         4.0       NaN       5.0     ...             NaN         NaN
# 15         5.0       NaN       5.0     ...             NaN         NaN
# 16         4.0       NaN       NaN     ...             NaN         NaN
# 17         6.0       6.0       NaN     ...             NaN         NaN
# 18         5.0       3.0       NaN     ...             NaN         NaN
# 19         6.0       6.0       6.0     ...             NaN         NaN
# 20         NaN       NaN       NaN     ...             NaN         NaN
# 21         4.0       6.0       NaN     ...             NaN         NaN
# 22         4.0       5.0       5.0     ...             NaN         NaN
# 23         5.0       6.0       NaN     ...             NaN         NaN
# 24         5.0       5.0       6.0     ...             NaN         NaN
# 25         4.0       NaN       6.0     ...             NaN         NaN
# 26         5.0       NaN       6.0     ...             NaN         NaN
# 27         NaN       5.0       6.0     ...             NaN         NaN
# 28         NaN       5.0       NaN     ...             NaN         NaN
# 29         NaN       NaN       NaN     ...             NaN         NaN
# ...        ...       ...       ...     ...             ...         ...
# 5025       NaN       NaN       NaN     ...             NaN         NaN
# 5026       5.0       6.0       NaN     ...             NaN         NaN
# 5027       4.0       3.0       4.0     ...             NaN         NaN
# 5028       5.0       5.0       6.0     ...             NaN         NaN
# 5029       5.0       6.0       NaN     ...             NaN         NaN
# 5030       NaN       NaN       NaN     ...             NaN         NaN
# 5035         NaN         NaN         NaN         NaN         NaN         NaN
# 5036         NaN         NaN         NaN         NaN         NaN         NaN
# 5037         NaN         NaN         NaN         NaN         NaN         NaN
# 5038         NaN         NaN         NaN         NaN         NaN         NaN
# 5039         NaN         NaN         NaN         NaN         NaN         NaN
# 5040         NaN         NaN         NaN         NaN         NaN         NaN
# 5041         NaN         NaN         NaN         NaN         NaN         NaN
# 5042         NaN         NaN         NaN         NaN         NaN         NaN
# 5043         NaN         NaN         NaN         NaN         NaN         NaN
# 5044         NaN         NaN         NaN         NaN         NaN         NaN
# 5045         NaN         NaN         NaN         NaN         NaN         NaN
# 5046         NaN         NaN         NaN         NaN         NaN         NaN
# 5047         NaN         NaN         NaN         NaN         NaN         NaN
# 5048         NaN         NaN         NaN         NaN         NaN         NaN
# 5049         NaN         NaN         NaN         NaN         NaN         NaN
# 5050         NaN         NaN         NaN         NaN         NaN         NaN
# 5051         NaN         NaN         NaN         NaN         NaN         NaN
# 5052         NaN         NaN         NaN         NaN         NaN         NaN
# 5053         NaN         NaN         NaN         NaN         NaN         NaN
# 5054         NaN         NaN         NaN         NaN         NaN         NaN
#
#       Score.1559  Score.1629
# 0            NaN         NaN
# 1            NaN         NaN
# 2            NaN         NaN
# 3            NaN         NaN
# 4            NaN         NaN
# 5            NaN         NaN
# 6            NaN         NaN
# 7            NaN         NaN
# 8            NaN         NaN
# 9            NaN         NaN
# 10           NaN         NaN
# 11           NaN         NaN
# 12           NaN         NaN
# 13           NaN         NaN
# 14           NaN         NaN
# 15           NaN         NaN
# 16           NaN         NaN
# 17           NaN         NaN
# 18           NaN         NaN
# 19           NaN         NaN
# 20           NaN         NaN
# 21           NaN         NaN
# 22           NaN         NaN
# 23           NaN         NaN
# 24           NaN         NaN
# 25           NaN         NaN
# 26           NaN         NaN
# 27           NaN         NaN
# 28           NaN         NaN
# 29           NaN         NaN
# ...          ...         ...
# 5025         NaN         NaN
# 5026         NaN         NaN
# 5027         NaN         NaN
# 5028         NaN         NaN
# 5029         NaN         NaN
# 5030         NaN         NaN
# 5031         NaN         NaN
# 5032         NaN         NaN
# 5033         NaN         NaN
# 5034         NaN         NaN
# 5035         NaN         NaN
# 5036         NaN         NaN
# 5037         NaN         NaN
# 5038         NaN         NaN
# 5039         NaN         NaN
# 5040         NaN         NaN
# 5041         NaN         NaN
# 5042         NaN         NaN
# 5043         NaN         NaN
# 5044         NaN         NaN
# 5045         NaN         NaN
# 5046         NaN         NaN
# 5047         NaN         NaN
# 5048         NaN         NaN
# 5049         NaN         NaN
# 5050         NaN         NaN
# 5051         NaN         NaN
# 5052         NaN         NaN
# 5053         NaN         NaN
# 5054         NaN         NaN
#
# [5055 rows x 1620 columns]

# %%
##### webtrain
for x in range(0, m):
    for y in range(0,m):
        a.append(pd.Series.count(list(set(webtrain.iloc[x]).intersection(set(webtrain.iloc[y])))))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-66-6dd578e08d0a> in <module>()
#       1 for x in range(0, m):
#       2     for y in range(0,m):
# ----> 3         a.append(pd.Series.count(list(set(webtrain.iloc[x]).intersection(set(webtrain.iloc[y])))))
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
# -> 1328             return self._getitem_axis(key, axis=0)
#    1329
#    1330     def _is_scalar_access(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1749             self._is_valid_integer(key, axis)
#    1750
# -> 1751             return self._get_loc(key, axis=axis)
#    1752
#    1753     def _convert_to_indexer(self, obj, axis=0, is_setter=False):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _get_loc(self, key, axis)
#     137
#     138     def _get_loc(self, key, axis=0):
# --> 139         return self.obj._ixs(key, axis=axis)
#     140
#     141     def _slice(self, obj, axis=0, kind=None):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _ixs(self, i, axis)
#    1887                     copy = True
#    1888                 else:
# -> 1889                     new_values = self._data.fast_xs(i)
#    1890                     if is_scalar(new_values):
#    1891                         return new_values
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in fast_xs(self, loc)
#    3554             # result[blk.mgr_locs] = blk._slice((slice(None), loc))
#    3555             for i, rl in enumerate(blk.mgr_locs):
# -> 3556                 result[rl] = blk._try_coerce_result(blk.iget((i, loc)))
#    3557
#    3558         return result
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in iget(self, i)
#     330         return self.values[loc]
#     331
# --> 332     def iget(self, i):
#     333         return self.values[i]
#     334
#
# KeyboardInterrupt:

# %%
outfile = open('../output/webtrain_a.csv','w')
out = csv.writer(outfile)
out.writerows(map(lambda x: [x], a))
outfile.close()
